# %%
import pandas as pd

# %%
obama_sotu = pd.read_csv("/Users/cynthiachen/Desktop/Obama_Sotu.csv")

# %%
row0 = obama_sotu.iloc[0]
text0 = row0['Text']
print(text0)
# Out:
# 9:11 P.M. EST
#
#
#
#
# 	THE PRESIDENT:  Madam Speaker, Vice President Biden, members of Congress, distinguished guests, and fellow Americans:
#
#
# 	Our Constitution declares that from time to time, the President shall give to Congress information about the state of our union.  For 220 years, our leaders have fulfilled this duty. They've done so during periods of prosperity and tranquility.  And they've done so in the midst of war and depression; at moments of great strife and great struggle.
#
#
# ...

# %%
import re
# Get rid of all audience reaction in parentheses like Applause or Laughter
obama_sotu['Text'] = obama_sotu['Text'].str.replace(r'\(.*?\)', '', regex=True)

# %%
import os  
os.makedirs('folder/subfolder', exist_ok=True)  
obama_sotu.to_csv("/Users/cynthiachen/Desktop/Obama_Sotu_Final.csv")

# %%
obama_df = pd.read_csv("/Users/cynthiachen/Desktop/DLCL Final Project/Obama_Cleaned.csv")

# %%
obama_df.head()
# Out:
#    Unnamed: 0 web.scraper.order  \
# 0           1      1700520694-1
# 1           2      1700520697-2
# 2           3      1700520700-3
# 3           4      1700520703-4
# 4           5      1700520706-5
#
#                                web.scraper.start.url  \
# 0  https://obamawhitehouse.archives.gov/briefing-...
# 1  https://obamawhitehouse.archives.gov/briefing-...
# 2  https://obamawhitehouse.archives.gov/briefing-...
# 3  https://obamawhitehouse.archives.gov/briefing-...
# 4  https://obamawhitehouse.archives.gov/briefing-...
#
#                                               speech  \
# 0  Remarks of the President in Welcoming Senior S...
# 1         President Barack Obama's Inaugural Address
# 2  Remarks by the President Before the Bipartisan...
# 3  WEEKLY ADDRESS: President Barack Obama Discuss...
# 4  Remarks by the President After Meeting With Ho...
#
#                                          speech.href  \
# 0  https://obamawhitehouse.archives.gov/the-press...
# ...

# %%
print(type(obama_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
for i, j in obama_df.iterrows():
    # j is the series of rows, i is the row's index
    text = j.get(key = 'Text')
    print(text)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Let's take the first as an example...
row1 = obama_df.iloc[0]
text1 = row1['Text']
print(text1)
# Out:
# THE WHITE HOUSE
#
#   Office of the Press Secretary
#   __________________________________________________________________________________________________
#   For Immediate Release January 21, 2009
#
#   REMARKS BY THE PRESIDENT IN WELCOMING SENIOR STAFF AND CABINET SECRETARIES TO THE WHITE HOUSE
#
#   Room 450
#   Eisenhower Executive Office Building
#
#   1:18 P.M. EST
#
#   THE PRESIDENT: Hello, everybody. Please be seated. Still getting used to that whole thing. (Laughter.) Please be seated. Thank you so much. I wanted to get everyone together on the first day to welcome you to the White House.
#
# ...

# %%
import re
reg1 = r"(?<=THE PRESIDENT:\s)[\s\S]*?(?=NAME_OF_JOURNALIST:\s|\s*\Z)"

#reg=re.compile(r"(?ms)^\s*THE PRESIDENT:\s*[\r\n]+(.+?)^[\s\w]+:\s*$")
#for m in reg.finditer(text1):
#    print(m)
    #print(m.group(1))

#matches = re.finditer(reg1, text1, re.DOTALL)
#for matchNum, match in enumerate(matches):
#    matchNum = matchNum + 1
#    print ("Match {matchNum} was found at {start}-{end}: {match}".format(matchNum = matchNum, start = match.start(), end = match.end(), match = match.group()))
for text in re.findall(r"(?<=THE PRESIDENT:).*?(?=NAME_OF_JOURNALIST:)", text1, flags=re.DOTALL):
    print(text.strip())

# %%
# Next: weekly speeches
